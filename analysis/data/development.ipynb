# %% [markdown]
# ## `/download`
# #### Development notebook the `/download` functionality
#
# This is a development notebook for the `/download` submodule, which focuses on retrieving the data retrieved from multiple data sources.
#
# The larger roadmap for this module is being defined alongside tests and architecture but these are the base level functions necssary for functionality, and can therefore be developed in isolation. This can also be generally considered the introduction level.

# %% [markdown]
# #### Problem 1
#
# Using [Quandl](https://www.quandl.com/tools/python) construct a class that can be used to retrieve and update information from a list of tickers.

# %%
# Add as many as you need
import datetime
import pandas 

# Modify as necessary
class Stock:
    """
    A stock object that uses a given name and ticker to retrieve and store data between the right dates.
    
    Unless otherwise specified, the default end date is always the current day. 
    """
    
    
    def __init__(self, name, ticker, start_date, end_date):
        self.name = name
        self.ticker = ticker
        self.start_date = start_date
        self.end_date = end_date
        pass
    
    def setup(self):
        """
        Creates a pandas DataFrame to recieve and hold all stock data.
        """
        pass 
    
    def get(self):
        """
        Gets all the data from start to end date from Quandl.
        """
        pass
        
    def update(self):
        """
        Updates the data to a new start date as necessary. 
        """      
        pass

# %%
# Example

AAPL = Stock('Apple', 'AAPL', start_date='2001-01-01', end_date="2017-01-01")

# %%
# Stock retrieval example using on Pandas Data Reader
# Build an equivalent version using Quandl 

import pandas_datareader
import datetime

start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2013, 1, 27)

pandas_datareader.get_data_google('GOOG')
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2010-01-04  313.16  314.44  311.81  313.06        NaN
# 2010-01-05  313.28  313.61  310.46  311.68        NaN
# 2010-01-06  312.62  312.62  302.88  303.83        NaN
# 2010-01-07  304.40  304.70  296.03  296.75        NaN
# 2010-01-08  295.70  301.32  294.26  300.71        NaN
# 2010-01-11  301.93  301.93  296.72  300.25        NaN
# 2010-01-12  298.74  298.78  293.71  294.94        NaN
# 2010-01-13  287.96  293.90  286.66  293.25        NaN
# 2010-01-14  291.66  296.80  291.11  294.63        NaN
# 2010-01-15  295.50  296.48  288.73  289.71        NaN
# 2010-01-19  290.45  294.91  287.86  293.52        NaN
# 2010-01-20  292.70  292.70  287.36  289.91        NaN
# 2010-01-21  291.43  293.12  285.84  291.20        NaN
# 2010-01-22  281.97  285.01  267.16  274.73        NaN
# 2010-01-25  273.02  274.66  267.49  269.73        NaN
# 2010-01-26  268.72  274.53  267.88  270.94        NaN
# ...
